# %% [markdown]
# # Carnet d'exercices
#
# Nous allons utiliser jupyter qui permet d'avoir dans un fichier html des véritables morceaux de Python.
#
# <table><tr><td>Tout repose sur cette barre d'icônes</td><td> <IMG SRC="run.png"></td><td> en haut de cette page.</td></tr>
# <tr><td></td><td>**run cell, interrupt kernel, restart kernel**</td><td></td></tr></table>
#
# L'icône **run cell**, qui est la plus à gauche dans la barre, permet de faire fonctionner une cellule (paragraphe)
#
# - Elle permet d'exécuter du code source Python (code).
# - Elle permet d'afficher correctement les paragraphes d'explications (markdown)
#
# L'icône **interrupt kernel**, qui est au centre dans la barre, permet d'arrêter du code Python "planté".
#
# L'icône **restart kernel**, qui est la plus à droite dans la barre, permet de remettre Python à zéro.
#
# Essayez l'icône **Run cell** sur le code suivant pour le voir exécuté.

# %%
chaine="Mon prénom est john"
print(chaine)

# %% [markdown]
# ## Exercice 1
# Saisir une commande permettant d'obtenir le nombre de caractères de la variable chaine

# %% [markdown]
# ## Exercice 2
# Saisir une commande permettant d'obtenir le caractère de la variable chaine situé à la place 5 ?
# Le résultat est-il celui attendu ?

# %% [markdown]
# ## Exercice 3
# Saisir une commande permettant d'obtenir le caractère de la variable chaine situé à la place 5 ? Le résultat est-il celui attendu ?

# %% [markdown]
# ## Exercice 4
# Écrire une fonction sequenceADN(n) ayant pour paramètre d’entrée un entier naturel 𝑛 et renvoyant une séquence d’ADN aléatoire de longueur 𝑛. On pourra utiliser la fonction choice(range(4)) de la  bibliothèque random pour obtenir un nombre aléatoire entre 0 et 3 avec la correspondance
#
# <table>
#    <tr>
#        <td> 0 </td>
#        <td> 1 </td>
#        <td> 2 </td>
#        <td> 3 </td>
#    </tr>
#    <tr>
#        <td> A </td>
#        <td> T </td>
#        <td> C </td>
#        <td> G </td>
#    </tr>
#
# </table>

# %% [markdown]
# ## Exercice 5
# Transcription de l’ADN en ARN. Lors de la transcription:
# - la thymine T est remplacée par l’Uracile U,
# - la Cythosine C est remplacée par la Guanine G et inversement
# Compléter le programme suivant permettant d'afficher l'ARN correspondant

# %%
chaineADN="TCAGTGACCATTGACGT"



print(chaineARN)
